# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv('C:/Users/jayjr/Downloads/Employee_Compensation_SF.csv')

# %%
data.shape
# Out:
# (291825, 22)

# %%
data.head()
# Out:
#   Year Type  Year  Organization Group Code    Organization Group  \
# 0    Fiscal  2016                        1     Public Protection
# 1  Calendar  2013                        5  Culture & Recreation
# 2  Calendar  2015                        4      Community Health
# 3    Fiscal  2015                        4      Community Health
# 4    Fiscal  2014                        5  Culture & Recreation
#
#   Department Code                      Department  Union Code  \
# 0             DAT               District Attorney       311.0
# 1             ART                 Arts Commission       790.0
# 2             DPH                   Public Health       535.0
# 3             DPH                   Public Health       250.0
# 4             REC  Recreation and Park Commission       790.0
#
#                                Union Job Family Code  \
# 0   Municipal Attorneys' Association            8100
# 1   SEIU - Miscellaneous, Local 1021            1800
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291825 entries, 0 to 291824
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Year Type                291825 non-null  object
#  1   Year                     291825 non-null  int64
#  2   Organization Group Code  291825 non-null  int64
#  3   Organization Group       291825 non-null  object
#  4   Department Code          291825 non-null  object
#  5   Department               291825 non-null  object
#  6   Union Code               291782 non-null  float64
#  7   Union                    291782 non-null  object
#  8   Job Family Code          291780 non-null  object
#  9   Job Family               291780 non-null  object
#  10  Job Code                 291825 non-null  object
#  11  Job                      291825 non-null  object
#  12  Employee Identifier      291825 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['Year Type', 'Year', 'Organization Group Code', 'Organization Group',
#        'Department Code', 'Department', 'Union Code', 'Union',
#        'Job Family Code', 'Job Family', 'Job Code', 'Job',
#        'Employee Identifier', 'Salaries', 'Overtime', 'Other Salaries',
#        'Total Salary', 'Retirement', 'Health/Dental', 'Other Benefits',
#        'Total Benefits', 'Total Compensation'],
#       dtype='object')

# %%
for i in data.columns:
    print(i)
    print(data[i].unique())
# Out:
# Year Type
# ['Fiscal' 'Calendar']
# Year
# [2016 2013 2015 2014]
# Organization Group
# ['Public Protection' 'Culture & Recreation' 'Community Health'
#  'Public Works, Transportation & Commerce'
#  'General Administration & Finance'
#  'Human Welfare & Neighborhood Development'
#  'General City Responsibilities']
# Department
# ['District Attorney' 'Arts Commission' 'Public Health'
#  'Recreation and Park Commission' 'General Services Agency - Public Works'
#  'Public Library' 'Assessor/Recorder' 'Police' 'Sheriff'
#  'Airport Commission' 'Municipal Transportation Agency' 'Human Services'
#  'General Services Agency - City Admin' 'PUC Water Department'
#  'PUC Public Utilities Commission' 'Fire Department' 'Superior Court'
#  'Department of Emergency Management' 'PUC Wastewater Enterprise'
#  'War Memorial' 'Fine Arts Museum' 'Environment' 'Rent Arbitration Board'
#  'Board of Supervisors' 'Juvenile Probation' 'Treasurer/Tax Collector'
# ...

# %%
data.describe().iloc[:,-9:]
# Out:
#             Salaries       Overtime  Other Salaries   Total Salary  \
# count  291825.000000  291825.000000   291825.000000  291825.000000
# mean    63210.172887    4406.877440     3781.032870   71398.083196
# std     44660.462305   11079.405928     7697.665317   52224.214099
# min    -68771.780000  -12308.660000   -19131.100000  -68771.780000
# 25%     23281.920000       0.000000        0.000000   25276.010000
# 50%     62519.120000       0.000000      697.080000   67847.870000
# 75%     92910.710000    2766.580000     4621.480000  103148.090000
# max    515101.800000  227313.620000   342802.630000  515101.800000
#
#           Retirement  Health/Dental  Other Benefits  Total Benefits  \
# count  291825.000000  291825.000000   291825.000000   291825.000000
# mean    12937.728957    8921.893732     4644.276407    26503.899096
# std      9785.064808    4900.318083     3787.907010    16800.143147
# min    -30621.430000   -2940.470000   -10636.500000   -21295.150000
# ...

# %%
Categorical_Values=['Year Type','Year','Organization Group Code','Organization Group','Department Code','Department',
                    'Union Code', 'Union','Job Family Code', 'Job Family', 'Job Code', 'Job','Employee Identifier']
Numeric_values=['Salaries','Overtime','Other Salaries','Total Salary','Retirement','Health/Dental','Other Benefits',
                'Total Benefits']

# %%
data.drop(columns=['Organization Group Code','Union Code','Department Code','Job Family Code','Job Code'],inplace=True)

# %%
data['Union'].fillna('temporily',inplace=True)

# %%
data['Job Family'].fillna('No Groups',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291825 entries, 0 to 291824
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Year Type            291825 non-null  object
#  1   Year                 291825 non-null  int64
#  2   Organization Group   291825 non-null  object
#  3   Department           291825 non-null  object
#  4   Union                291825 non-null  object
#  5   Job Family           291825 non-null  object
#  6   Job                  291825 non-null  object
#  7   Employee Identifier  291825 non-null  int64
#  8   Salaries             291825 non-null  float64
#  9   Overtime             291825 non-null  float64
#  10  Other Salaries       291825 non-null  float64
#  11  Total Salary         291825 non-null  float64
#  12  Retirement           291825 non-null  float64
#  13  Health/Dental        291825 non-null  float64
# ...

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.barplot(x=data['Job Family'].value_counts().values,y=data['Job Family'].value_counts().index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-5bf370ccaeb0> in <module>
#       1 sns.set(rc={'figure.figsize':(15,15)})
#       2 sns.barplot(x=data['Job Family'].value_counts().values,y=data['Job Family'].value_counts().index)
# ----> 3 plt.xLabel('car')
#
# AttributeError: module 'matplotlib' has no attribute 'xLabel'

# %%
sns.set(rc={'figure.figsize':(20,16)})

sns.barplot(x=data['Total Salary'],y=data['Job Family'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Salary', ylabel='Job Family'>

# %%
sns.barplot(x=data['Total Benefits'],y=data['Job Family'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Benefits', ylabel='Job Family'>

# %%
sns.barplot(x=data['Total Compensation'],y=data['Job Family'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Compensation', ylabel='Job Family'>

# %%
data['Total Benefits'].corr(data['Total Salary'])
# Out:
# 0.9027976261839518

# %%
data['Total Benefits'].corr(data['Total Compensation'])
# Out:
# 0.9434988497527604

# %%
data['Total Salary'].corr(data['Total Compensation'])
# Out:
# 0.9943018638754008

# %%
sns.set(rc={'figure.figsize':(20,19)})
sns.barplot(x=data['Total Compensation'],y=data['Department'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Compensation', ylabel='Department'>

# %%
sns.barplot(x=data['Total Compensation'],y=data['Organization Group'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Compensation', ylabel='Organization Group'>

# %%
sns.barplot(x=data['Total Compensation'],y=data['Union'],ci=None)
# Out:
# <AxesSubplot:xlabel='Total Compensation', ylabel='Union'>

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.boxplot(data=data,x='Total Compensation')
# Out:
# <AxesSubplot:xlabel='Total Compensation'>

# %%
sns.heatmap(data[['Total Salary','Overtime','Other Salaries','Salaries']].corr())
# Out:
# <AxesSubplot:>
