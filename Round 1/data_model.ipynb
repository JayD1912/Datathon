# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

import pandas as pd

# %%
training=pd.read_csv('C:/Users/jayjr/Downloads/train_final.csv')
testing=pd.read_csv('C:/Users/jayjr/Downloads/test_final.csv')
training.drop(columns=['Consumer complaint narrative','Tags','Consumer disputed?'],inplace=True)
testing.drop(columns=['Consumer complaint narrative','Tags','Consumer disputed?'],inplace=True)

# %%
X_train=training.iloc[:,0:-1]
X_train
# Out:
#          Unnamed: 0  Complaint_ID  Date received  Product  Issue  \
# 0                 0       2535701           2569       10    139
# 1                 1       3314889           2715        4    117
# 2                 2       3612478           1852        6     75
# 3                 3       2069704           2946        0     54
# 4                 4       3354927           3039        7    146
# ...             ...           ...            ...      ...    ...
# 1048570     1048570       3796247           2905       10    148
# 1048571     1048571       3933702            795        6     75
# 1048572     1048572       3361930           3075       10     11
# 1048573     1048573       4003293            878        6     75
# 1048574     1048574       3625596           1942        6     75
#
#          Submitted via  Date sent to company  Sub-product  Sub-issue  \
# 0                    1                  2300           10        220
# ...

# %%
y_train=training.iloc[:,-1]
y_train
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1048570    1
# 1048571    1
# 1048572    1
# 1048573    1
# 1048574    1
# Name: Timely response?, Length: 1048575, dtype: int64

# %%
X_test=testing.iloc[:,:]
X_test
# Out:
#         Unnamed: 0  Complaint_ID  Date received  Product  Issue  \
# 0                0       3839774           3203       15     75
# 1                1       2139831           1764        2    135
# 2                2       4084614           3336        6     75
# 3                3       3461505           2925        6     75
# 4                4       2854433           2305        6    112
# ...            ...           ...            ...      ...    ...
# 459689      459689        342950            461       10     80
# 459690      459690       2599961           2076        4    112
# 459691      459691       3824572           3194        6     72
# 459692      459692       1418953           1288       10     82
# 459693      459693       3532501           2994        7     13
#
#         Submitted via  Date sent to company  Sub-product  Sub-issue  \
# 0                   5                  3121           22          4
# ...

# %%
ranfor=RandomForestClassifier(random_state=1000,n_estimators=300)
ranfor.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=1000)

# %%
y_pred = ranfor.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
dic={0:'No',1:'Yes'}
list1=X_test.iloc[:,1]
list2=[]
for i in y_pred:
    list2.append(dic[i])
data1 = {'Complaint ID':list1,
        'Timely response?':list2}
  
data2=pd.DataFrame(data1)
data2.to_csv('for2.csv')

# %%
classifier = SVC(kernel = 'linear', random_state = 42)
classifier.fit(X_train, y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-c82449abe233> in <module>
# ----> 1 gnb = GaussianNB(random_state=42)
#       2 gnb.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: __init__() got an unexpected keyword argument 'random_state'

# %%
y_pred = gnb.predict(X_test)

# %%
print("Accuracy : ",accuracy_score(y_pred,y_test)*100)
# Out:
# Accuracy :  97.8616714477539

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# C:\Users\jayjr\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=log.predict(X_test)

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=classifier.predict(X_test)
